# %% [markdown]
# # Análise de dados com Python e Pandas

# %% [markdown]
# ![Python_pandas.jpg](attachment:Python_pandas.jpg)

# %%
#importar bibliotecas
import pandas as pd

# %%
#carregar dados
df = pd.read_excel('dados/AdventureWorks.xlsx')

# %% [markdown]
# # Análise exploratória de dados

# %%
# Shape
df.shape
# Out:
# (904, 16)

# %%
#Visualizando as 5 primeiras linhas
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
#Visualizando as últimas linhas
df.tail(10)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 894 2008-12-17 2008-12-22      307        1226       19111  200812174CS669
# 895 2009-01-11 2009-01-18      307        1155       19113  200901114CS680
# 896 2009-03-04 2009-03-15      307        1155       19117  200903044CS706
# 897 2009-06-12 2009-06-22      307        1226       19126  200906124CS716
# 898 2009-06-25 2009-07-06      307        1155       19127  200906254CS717
# 899 2008-03-22 2008-04-04      306        1226       19049  200803224CS555
# 900 2008-10-04 2008-10-15      306        1155       19057  200810044CS636
# 901 2008-12-11 2008-12-15      306        1155       19060  200812114CS676
# 902 2008-12-17 2008-12-21      306        1226       19060  200812174CS676
# 903 2008-12-21 2008-12-25      306        1155       19060  200812214CS676
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# ...

# %%
# Verifica o total de valores únicos por coluna
df.nunique()
# Out:
# Data Venda        483
# Data Envio        478
# ID Loja             3
# ID Produto          9
# ID Cliente        168
# No. Venda         821
# Custo Unitário      5
# Preço Unitário      5
# Quantidade         56
# Valor Desconto    158
# Valor Venda       217
# Produto             9
# Fabricante          3
# Marca               3
# Classe              2
# Cor                 5
# dtype: int64

# %%
# Verificando valores nulos
df.isna().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# dtype: int64

# %%
# Tipos de dados
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
#Nomes de colunas
df.columns
# Out:
# Index(['Data Venda', 'Data Envio', 'ID Loja', 'ID Produto', 'ID Cliente',
#        'No. Venda', 'Custo Unitário', 'Preço Unitário', 'Quantidade',
#        'Valor Desconto', 'Valor Venda', 'Produto', 'Fabricante', 'Marca',
#        'Classe', 'Cor'],
#       dtype='object')

# %%
#Amostra do conjunto de dados
df.sample(5)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 37  2009-06-03 2009-06-15      306        1178       19068  200906034CS748
# 861 2009-12-20 2010-01-01      306        1178       19078  200912204CS780
# 808 2009-02-09 2009-02-19      307         384       19116  200902093CS699
# 848 2008-03-22 2008-04-04      306        1203       19049  200803224CS555
# 283 2008-05-08 2008-05-20      199        2497       18838  200805085CS606
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 37           330.66          998.00           6             0.0       5988.0
# 861          330.66          998.00           6          1197.6       4790.4
# 808          348.58          758.00           6           909.6       3638.4
# 848          324.69          980.00           6           411.6       5468.4
# 283            5.09            9.99         120             0.0       1198.8
#
# ...

# %%
# Range de datas do período que ocorreram as vendas 
print('Data Mínima:', df['Data Venda'].min())
print('Data Máxima:', df['Data Venda'].max())
# Out:
# Data Mínima: 2008-01-02 00:00:00
# Data Máxima: 2009-12-31 00:00:00

# %%
#Limpeza de algumas colunas do dataset para que ele fique menor e mais legível
df.drop(['Data Envio', 'No. Venda', 'Fabricante', 'Classe'], axis = 1, inplace = True)

# %%
#Renomear colunas
df.rename(columns={'Valor Desconto': 'Desconto','Valor Venda': 'Venda' }, inplace = True)

# %%
df.head()
# Out:
#   Data Venda  ID Loja  ID Produto  ID Cliente  Custo Unitário  Preço Unitário  \
# 0 2008-05-09      199         384       18839          348.58           758.0
# 1 2008-05-12      306         384       19051          348.58           758.0
# 2 2008-05-14      306         384       19052          348.58           758.0
# 3 2008-05-21      306         384       19052          348.58           758.0
# 4 2008-06-20      306         384       19053          348.58           758.0
#
#    Quantidade  Desconto   Venda                                Produto  \
# 0           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
# 1           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
# 2           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
# 3           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
# 4           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
#
#              Marca  Cor
# 0  Adventure Works  Red
# ...

# %%
#Produtos vendidos pela empresa
df['Produto'].unique()
# Out:
# array(['Adventure Works Laptop15.4W M1548 Red',
#        "Fabrikam Trendsetter 1/3'' 8.5mm X200 White",
#        "Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey",
#        "Fabrikam Trendsetter 2/3'' 17mm X100 Grey",
#        "Fabrikam Trendsetter 2/3'' 17mm X100 Black",
#        "Fabrikam Trendsetter 1/3'' 8.5mm X200 Black",
#        'Adventure Works Laptop15.4W M1548 Black',
#        'Headphone Adapter for Contoso Phone E130 Silver',
#        'Headphone Adapter for Contoso Phone E130 White'], dtype=object)

# %%
#Quantidade de produtos vendidos por cada loja
df["ID Loja"].value_counts(ascending=False)
# Out:
# 307    319
# 199    307
# 306    278
# Name: ID Loja, dtype: int64

# %%
#Soma da quantidade de produtos vendidos
df["Quantidade"].sum()
# Out:
# 56907

# %%
#Gráfico com as informações de total de venda por lojas
df["ID Loja"].value_counts(ascending=False).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Receita = Quantidade * Valor_Unitario

# %%
# Extrai o mês da fatura
df['Ano'] = df['Data Venda'].map(lambda date: date.year)

# %%
df.head()
# Out:
#   Data Venda  ID Loja  ID Produto  ID Cliente  Custo Unitário  Preço Unitário  \
# 0 2008-05-09      199         384       18839          348.58           758.0
# 1 2008-05-12      306         384       19051          348.58           758.0
# 2 2008-05-14      306         384       19052          348.58           758.0
# 3 2008-05-21      306         384       19052          348.58           758.0
# 4 2008-06-20      306         384       19053          348.58           758.0
#
#    Quantidade  Desconto   Venda                                Produto  \
# 0           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
# 1           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
# 2           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
# 3           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
# 4           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
#
#              Marca  Cor   Ano
# 0  Adventure Works  Red  2008
# ...

# %%
# Calcular a receita
df["Receita"] = df["Quantidade"] * df["Preço Unitário"]

# %%
df.head()
# Out:
#   Data Venda  ID Loja  ID Produto  ID Cliente  Custo Unitário  Preço Unitário  \
# 0 2008-05-09      199         384       18839          348.58           758.0
# 1 2008-05-12      306         384       19051          348.58           758.0
# 2 2008-05-14      306         384       19052          348.58           758.0
# 3 2008-05-21      306         384       19052          348.58           758.0
# 4 2008-06-20      306         384       19053          348.58           758.0
#
#    Quantidade  Desconto   Venda                                Produto  \
# 0           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
# 1           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
# 2           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
# 3           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
# 4           6       0.0  4548.0  Adventure Works Laptop15.4W M1548 Red
#
#              Marca  Cor   Ano  Receita
# ...

# %%
#Retornar maior faturamento
df["Receita"].max()
# Out:
# 31360.0

# %%
#Retornando a menor receita
df["Receita"].min()
# Out:
# 159.84

# %%
# Agrupa a receita por mês/ano
dados_receita = df.groupby(['Ano']).agg({'Receita': sum}).reset_index()

# %%
dados_receita.head(10)
# Out:
#     Ano     Receita
# 0  2008  3480041.67
# 1  2009  3127531.93

# %%
dados_receita.tail(10)
# Out:
#     Ano     Receita
# 0  2008  3480041.67
# 1  2009  3127531.93

# %%
#Selecionando apenas as vendas de 2008
df_2008 = df[df["Ano"] == 2008]

# %%
df_2008.groupby(df_2008["Venda"])["Quantidade"].sum()
# Out:
# Venda
# 159.840        16
# 332.667        37
# 767.232       384
# 971.028       432
# 1198.800     1920
#              ...
# 23952.000      24
# 23976.000      48
# 25088.000      32
# 25174.800      28
# 29400.000      30
# Name: Quantidade, Length: 152, dtype: int64

# %%
#Selecionando apenas as vendas de 2009
df_2009 = df[df["Ano"] == 2009]

# %%
df_2009.groupby(df_2009["Venda"])["Quantidade"].sum()
# Out:
# Venda
# 351.648        44
# 479.520        48
# 591.408        74
# 1534.464     2112
# 1726.272      864
#              ...
# 17982.000      18
# 18816.000      24
# 19404.800      32
# 20419.080      22
# 22275.360      24
# Name: Quantidade, Length: 145, dtype: int64
